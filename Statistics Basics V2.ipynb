# %% [markdown]
# What is the normal body temperature for healthy humans? A random sample of 130 healthy human body temperatures provided by Allen Shoemaker yielded 98.25 degrees and standard deviation 0.73 degrees.
#
# Give a 99% confidence interval for the average body temperature of healthy people.

# %%
import numpy as np
from scipy import stats

# %%
sample_mean = 98.25
sample_std = 0.73
sample_size = 130
confidence_level = 0.99

# %%
standard_error = sample_std / np.sqrt(sample_size)

# %%
z_score = stats.norm.ppf((1 + confidence_level) / 2)

# %%
margin_of_error = z_score * standard_error

# %%
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# %%
print("99% Confidence Interval for the average body temperature of healthy people:")
print(f"({lower_bound:.3f}, {upper_bound:.3f}) degrees")
# Out:
# 99% Confidence Interval for the average body temperature of healthy people:
# (98.085, 98.415) degrees

# %% [markdown]
# The administrators for a hospital wished to estimate the average number of days required for inpatient treatment of patients between the ages of 25 and 34. A random sample of 500 hospital patients between these ages produced a mean and standard deviation equal to 5.4 and 3.1 days, respectively.
#
#
# Construct a 95% confidence interval for the mean length of stay for the population of patients from which the sample was drawn.

# %%
import scipy.stats as stats

# %%
sample_mean = 5.4
sample_std = 3.1
sample_size = 500
confidence_level = 0.95

# %%
z_score = stats.norm.ppf((1 + confidence_level) / 2)

# %%
standard_error = sample_std / np.sqrt(sample_size)

# %%
margin_of_error = z_score * standard_error

# %%
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("95% Confidence Interval for the mean length of stay:")
print(f"({lower_bound:.4f}, {upper_bound:.4f}) days")
# Out:
# 95% Confidence Interval for the mean length of stay:
# (5.1283, 5.6717) days

# %% [markdown]
# EXERCISE 3. The hourly wages in a particular industry are normally distributed with mean $13.20 and standard deviation $2.50. A company in this industry employs 40 workers, paying them an average of $12.20 per hour. Can this company be accused of paying substandard wages? Use an α = .01 level test. (Wackerly, Ex.10.18)
#
# CHECK: statistic: -2.5298221281347035, pvalue= 0.005706018193000826

# %%
population_mean = 13.20
population_std = 2.50
sample_size = 40
sample_mean = 12.20
alpha = 0.01

# %%
z = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# %%
p_value = stats.norm.cdf(z)

# %%
print("Test statistic:", z)
print("p-value:", p_value)
# Out:
# Test statistic: -2.5298221281347035
# p-value: 0.005706018193000826

# %% [markdown]
# EXERCISE 4.Shear strength measurements derived from unconfined compression tests for two types of soils gave the results shown in the following document (measurements in tons per square foot). Do the soils appear to differ with respect to average shear strength, at the 1% significance level?
#
# CHECK: statistic: 5.1681473319343345, pvalue= 2.593228732352821e-06

# %%
import pandas as pd
import os

current_dir = os.getcwd()

data = pd.read_csv(r"C:\Users\onur\Desktop\Notebooks Cls\07.04.24\soil - Sheet1.csv")

# %%
data.describe()
# Out:
#            Soil1      Soil2
# count  30.000000  35.000000
# mean    1.691800   1.417114
# std     0.206903   0.219184
# min     1.110000   1.053000
# 25%     1.572000   1.231000
# 50%     1.675000   1.379000
# 75%     1.865250   1.559000
# max     2.054000   1.878000

# %%
import numpy as np
import scipy.stats as stats

# %%
Soil1 = data['Soil1'].tolist()
Soil2 = data['Soil2'].tolist()

#_, p1 = stats.shapiro(Soil1)
#_, p2 = stats.shapiro(Soil2)

# %%
cleaned_data = data.dropna()
cleaned_data
# Out:
#     Soil1  Soil2
# 0   1.442  1.364
# 1   1.943  1.878
# 2   1.110  1.337
# 3   1.912  1.828
# 4   1.553  1.371
# 5   1.641  1.428
# 6   1.499  1.119
# 7   1.347  1.373
# 8   1.685  1.589
# 9   1.578  1.714
# 10  1.866  1.260
# 11  1.653  1.492
# 12  1.665  1.395
# 13  1.640  1.778
# 14  1.976  1.611
# 15  1.754  1.202
# 16  1.589  1.542
# 17  1.976  1.094
# 18  1.863  1.557
# 19  1.932  1.053
# 20  1.570  1.183
# 21  1.613  1.367
# 22  2.054  1.144
# 23  1.550  1.151
# 24  1.714  1.561
# 25  1.896  1.192
# 26  1.737  1.489
# 27  1.740  1.379
# 28  1.708  1.501
# 29  1.548  1.277

# %%
statistic, p_value = stats.ttest_ind(Soil1, Soil2)

# %%
print("Test Results:")
print("Statistic:", statistic)
print("p-value:", p_value)
# Out:
# Test Results:
# Statistic: nan
# p-value: nan

# %% [markdown]
# XERCISE 5. The following dataset is based on data provided by the World Bank (https://datacatalog.worldbank.org/dataset/education-statistics). World Bank Edstats.  2015 PISA Test Dataset
#
# Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent group (AS, EU, AF, NA, SA, OC).
# Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS) countries (assume normality and equal variances). Draw side-by-side box plots.
# CHECK: statistic=0.870055317967983, pvalue=0.38826888111307345

# %%
data_w = pd.read_csv(r"C:\Users\onur\Desktop\Notebooks Cls\07.04.24\2015 PISA Test - Sheet1.csv")

# %%
data_w
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 0           ALB             EU               63.252933  413.1570  405.2588
# 1           ARE             AS               90.500000  427.4827  433.5423
# 2           ARG             SA               68.043064  409.0333  425.3031
# 3           AUS             OC               84.560519  493.8962  502.9006
# 4           AUT             EU               83.940142  496.7423  484.8656
# ..          ...            ...                     ...       ...       ...
# 65          TUN             AF               48.519836  366.8180  361.0555
# 66          TUR             EU               53.744979  420.4540  428.3351
# 67          URY             SA               64.600000  417.9919  436.5721
# 68          USA            NaN               74.554202  469.6285  496.9351
# 69          VNM             AS               43.500000  494.5183  486.7738
#
#      Science
# 0   427.2250
# 1   436.7311
# 2   432.2262
# ...

# %%
continent_groups = {
    "AS": data[data["Continent_Code"] == "AS"],
    "EU": data[data["Continent_Code"] == "EU"],
    "AF": data[data["Continent_Code"] == "AF"],
    "NA": data[data["Continent_Code"] == "NA"],
    "SA": data[data["Continent_Code"] == "SA"],
    "OC": data[data["Continent_Code"] == "OC"]}

# %%
for continent, scores in continent_groups.items():
    print(f"\nDescriptive statistics for {continent_groups} Continent:")
    print(scores.describe())
# Out:
# Descriptive statistics for {'AS':    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 1           ARE             AS               90.500000  427.4827  433.5423
# 11          CHN             AS               50.300000  531.2961  493.9412
# 25          GEO             AS               47.569760  403.8332  401.2881
# 27          HKG             AS               84.948353  547.9310  526.6753
# 30          IDN             AS               21.976068  386.1096  397.2595
# 33          ISR             AS               77.352090  469.6695  478.9606
# 35          JOR             AS               60.114383  380.2590  408.1022
# 36          JPN             AS               91.058028  532.4399  515.9585
# 37          KAZ             AS               72.900000  459.8160  427.1410
# 38          KOR             AS               89.648631  524.1062  517.4367
# 39          LBN             AS               74.000000  396.2497  346.5490
# ...

# %%
math_scores_eu = data[data["Continent_Code"] == "EU"]["Math"]
math_scores_as = data[data["Continent_Code"] == "AS"]["Math"]

# %%
statistic, p_value = stats.ttest_ind(math_scores_eu, math_scores_as)

# %%
print("Test Results:")
print("Statistic:", statistic)
print("p-value:", p_value)
# Out:
# Test Results:
# Statistic: 0.870055317967983
# p-value: 0.38826888111307345
